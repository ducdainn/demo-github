# %%
from __future__ import division, print_function, unicode_literals
import math
import numpy as np 
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# %%
def grad(x):
    return 2*x + 5*np.cos(x)
def cost(x):
    return x**2 + 5*np.sin(x)
def myGD1(eta, x0):
    x = [x0]
    for it in range(100):
        x_new = x[-1] - eta*grad(x[-1])
        if abs(grad(x_new)) < 1e-3:
            break
        x.append(x_new)
    return (x, it)

# %%
(x1, it1) = myGD1(.1, -5)
(x2, it2) = myGD1(.1, 5)
print('Solution x1 = %f, cost = %f, obtained after %d iterations' % (x1[-1], cost(x1[-1]), it1))
print('Solution x2 = %f, cost = %f, obtained after %d iterations' % (x2[-1], cost(x2[-1]), it2))
# Out:
# Solution x1 = -1.110667, cost = -3.246394, obtained after 11 iterations
# Solution x2 = -1.110341, cost = -3.246394, obtained after 29 iterations

# %%
(x3, it3) = myGD1(.3, -5)
print('Solution: x = %f, f(x) = %f, after %d iterations' % (x3[-1], cost(x3[-1]), it3))
# Out:
# Solution: x = -1.109597, f(x) = -3.246392, after 99 iterations

# %%
x_vals = np.linspace(-10, 10, 400)
cost_vals = cost(x_vals)

fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(x_vals, cost_vals, label='cost(x)')
line, = ax.plot([], [], marker='o', color='r', label='Optimization Path')
ax.set_title('Optimization Path')
ax.set_xlabel('x')
ax.set_ylabel('cost(x)')
ax.legend()

def animate(frame):
    line.set_data(x1[:frame+1], [cost(x) for x in x1[:frame+1]])
    return line,

ani = FuncAnimation(fig, animate, frames=len(x1), interval=500)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

def grad(x):
    return 2*x + 5*np.cos(x)

def cost(x):
    return x**2 + 5*np.sin(x)

def myGD1(eta, x0):
    x = [x0]
    for it in range(100):
        x_new = x[-1] - eta*grad(x[-1])
        if abs(grad(x_new)) < 1e-3:
            break
        x.append(x_new)
    return (x, it)

(x1, it1) = myGD1(.1, -5)
(x2, it2) = myGD1(.1, 5)

x_vals = np.linspace(-10, 10, 400)
cost_vals = cost(x_vals)

fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(x_vals, cost_vals, label='cost(x)')
line, = ax.plot([], [], marker='o', color='r', label='Optimization Path')
ax.set_title('Optimization Path')
ax.set_xlabel('x')
ax.set_ylabel('cost(x)')
ax.legend()

def update(frame):
    line.set_data(x1[:frame+1], [cost(x) for x in x1[:frame+1]])
    return line,

ani = FuncAnimation(fig, update, frames=len(x1), blit=True, interval=200, repeat=False)
plt.show()
# Out:
# c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\animation.py:880: UserWarning: Animation was deleted without rendering anything. This is most likely not intended. To prevent deletion, assign the Animation to a variable, e.g. `anim`, that exists until you output the Animation using `plt.show()` or `anim.save()`.
#   warnings.warn(
